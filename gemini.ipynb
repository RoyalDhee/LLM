# %%
from google import genai
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
prompt = "Transalte the following English sentence into French: 'The weather is nice today'"

client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash", contents=prompt
)
print(response.text)
# Out:
# The most common and natural way to say "The weather is nice today" in French is:
#
# **Il fait beau aujourd'hui.**
#
# You could also say:
#
# **Le temps est beau aujourd'hui.** (Literally: "The weather is beautiful today.")
# **Le temps est agréable aujourd'hui.** (Literally: "The weather is pleasant today.")

# %%
from google import genai
from google.genai import types

client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="How does AI work?",
    config=types.GenerateContentConfig(
        thinking_config=types.ThinkingConfig(thinking_budget=0) # Disables thinking
    ),
)
print(response.text)
# Out:
# That's a fantastic question, and one that many people are curious about! The truth is, "AI" is a very broad term, and how it "works" depends on the specific type of AI we're talking about. However, I can give you a general overview of the core principles and common techniques.
#
# At its heart, **AI is about creating computer systems that can perform tasks that typically require human intelligence.**
#
# Here's a breakdown of the fundamental ideas:
#
# ---
#
# ### The Core Idea: Learning from Data
#
# Most modern AI, particularly the kind you hear about (like ChatGPT, image generators, self-driving cars), relies heavily on **Machine Learning (ML)**. The central idea of ML is:
#
# **Instead of being explicitly programmed for every single scenario, AI learns patterns and rules directly from large amounts of data.**
#
# Think of it like this:
#
# *   **Traditional Programming:** You give the computer step-by-step instructions: "IF the light is red, THEN stop."
# *   **Machine Learning:** You show the computer thousands of images of red lights and thousands of images of cars stopping, and it figures out the correlation itself.
#
# ---
#
# ### How Does This "Learning" Happen? (Key Concepts)
#
# 1.  **Data Collection and Preparation:**
#     *   AI needs vast amounts of relevant data: images, text, sounds, sensor readings, etc.
#     *   This data needs to be cleaned, labeled, and formatted so the AI can understand it. (e.g., tagging images of cats as "cat").
#
# 2.  **Models and Algorithms:**
#     *   An **AI model** is essentially a mathematical structure or program designed to learn.
#     *   An **algorithm** is the set of rules or instructions the model uses to process data and learn.
#     *   There are many different types of models and algorithms, each suited for different tasks (e.g., neural networks, decision trees, support vector machines).
#
# 3.  **Training:** This is the "learning" phase.
#     *   The model is fed the labeled data.
#     *   It tries to make predictions or find patterns in the data.
#     *   It then compares its predictions to the correct answers (from the labels).
#     *   If its prediction is wrong, the model adjusts its internal parameters (like knobs and dials) slightly to try and be more accurate next time. This adjustment process is often driven by **optimization algorithms** that aim to minimize errors.
#     *   This cycle of prediction, error calculation, and adjustment happens millions or billions of times until the model gets very good at the task.
#
# 4.  **Inference (or Prediction):**
#     *   Once trained, the model is deployed.
#     *   When it encounters new, unseen data (e.g., a new photo, a new text query), it uses the patterns it learned during training to make a prediction or generate an output.
#     *   It doesn't "think" in the human sense; it applies complex mathematical functions based on what it learned.
#
# ---
#
# ### Deep Learning: The AI Revolution
#
# A very powerful subset of Machine Learning is **Deep Learning (DL)**. It's responsible for many of the breakthroughs we see today.
#
# *   **Neural Networks:** Deep Learning uses **artificial neural networks**, which are inspired by the structure of the human brain (though vastly simplified). These networks consist of layers of interconnected "nodes" or "neurons."
# *   **Layers:** A "deep" neural network has many hidden layers between the input and output layers. Each layer learns to recognize different features or patterns in the data, building up from simple to complex. For example, in an image, one layer might detect edges, another might detect shapes, and a higher layer might combine these to recognize an eye or an ear.
# *   **Representation Learning:** Deep learning is particularly good at "representation learning," meaning it can automatically discover the best way to represent the input data for the task at hand, rather than relying on human engineers to hand-craft features.
#
# ---
#
# ### Examples of AI in Action (and how they generally work)
#
# *   **Image Recognition (e.g., identifying objects in photos):**
#     *   **Data:** Millions of images labeled with what they contain (cat, dog, car).
#     *   **Model:** A Convolutional Neural Network (CNN) is often used.
#     *   **Training:** The CNN learns to identify specific features (edges, textures, shapes) at different layers and combine them to recognize objects.
#     *   **Inference:** When shown a new image, it applies the learned features to classify the object.
#
# *   **Natural Language Processing (NLP) (e.g., ChatGPT, translation):**
#     *   **Data:** Vast amounts of text from the internet (books, articles, websites).
#     *   **Model:** Often uses Transformer models (a type of neural network).
#     *   **Training:** The model learns the statistical relationships between words, sentences, and concepts. It learns to predict the next word in a sequence given the preceding ones.
#     *   **Inference:** When you type a prompt, it uses these learned relationships to generate coherent and contextually relevant text, essentially predicting the most probable next words.
#
# *   **Recommendation Systems (e.g., Netflix, Amazon):**
#     *   **Data:** User ratings, viewing history, purchase history, item metadata.
#     *   **Model:** Various techniques, including collaborative filtering and neural networks.
#     *   **Training:** The model learns patterns in user preferences and item similarities. "People who liked X also liked Y."
#     *   **Inference:** Based on your past behavior and the behavior of similar users, it predicts what you might like next.
#
# *   **Self-Driving Cars:**
#     *   **Data:** Camera feeds, lidar data, radar data, GPS, human driving data.
#     *   **Model:** A complex system integrating many different AI models (for object detection, path planning, prediction of other vehicles' movements).
#     *   **Training:** Models learn to identify objects (pedestrians, other cars, traffic lights), predict their movement, and make decisions based on rules and learned probabilities.
#     *   **Inference:** The system processes real-time sensor data and makes decisions on steering, acceleration, and braking.
#
# ---
#
# ### Key Takeaways:
#
# *   **Data is Fuel:** AI's intelligence comes from the data it's trained on.
# *   **Patterns, Not Programming:** Modern AI learns patterns and relationships from data rather than being explicitly coded for every scenario.
# *   **Mathematical Models:** At its core, AI involves complex mathematical models and algorithms.
# *   **Optimization:** AI constantly refines itself during training to minimize errors.
# *   **Specialized Tasks:** Each AI is typically trained for a specific task or set of tasks.
# *   **No True Consciousness (Yet):** Current AI systems do not possess consciousness, emotions, or understanding in the human sense. They are powerful pattern-matching and prediction machines.
#
# I hope this gives you a clearer picture! It's a vast and rapidly evolving field, but the fundamental principles remain quite consistent.

# %%
from google import genai

client = genai.Client()
chat = client.chats.create(model="gemini-2.5-flash")

response = chat.send_message("I have 2 dogs in my house.")
print(response.text)

response = chat.send_message("How many paws are in my house?")
print(response.text)

for message in chat.get_history():
    print(f'role - {message.role}',end=": ")
    print(message.parts[0].text)
# Out:
# Oh, wonderful! Double the fun and double the love!
#
# What kind of dogs are they? Do they get along well?
#
# Anything specific you'd like to chat about regarding them, or just sharing the happy news?
# Based on your two dogs, and assuming each dog has 4 paws:
#
# **There are 8 paws in your house!**
# role - user: I have 2 dogs in my house.
# role - model: Oh, wonderful! Double the fun and double the love!
#
# What kind of dogs are they? Do they get along well?
#
# Anything specific you'd like to chat about regarding them, or just sharing the happy news?
# role - user: How many paws are in my house?
# role - model: Based on your two dogs, and assuming each dog has 4 paws:
#
# **There are 8 paws in your house!**
